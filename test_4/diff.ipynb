# %% [markdown]
# # Download Datasets

# %%
import pandas as pd

my_df = pd.read_csv('/content/drive/MyDrive/Father/camp2021/test_4/final_result.csv',index_col='Unnamed: 0')
father_df = pd.read_csv('/content/drive/MyDrive/Father/camp2021/test_4/df_ready_for_prediction.csv',index_col='Unnamed: 0')
father_price = pd.read_csv('/content/drive/MyDrive/Father/camp2021/test_4/hometask_completed_sample.csv',index_col='Unnamed: 0')

# %%
my_df=my_df.sort_index()

# %%
my_df
# Out:
#               price  rent_converted  ...  size_converted  noccup_converted
# 0      226300.00000      624.000000  ...              52               3.0
# 1      205797.80438      622.000000  ...              43               3.0
# 2      176050.00000      544.000000  ...              57               3.0
# 3      170650.00000      423.000000  ...              51               3.0
# 4      171100.00000      288.000000  ...              44               3.0
# ...             ...             ...  ...             ...               ...
# 20635   39050.00000      117.000000  ...              52               3.0
# 20636   38550.00000      191.000000  ...              63               3.0
# 20637   46150.00000      127.000000  ...              47               3.0
# 20638   42350.00000      140.000000  ...              43               3.0
# 20639   44700.00000      289.893963  ...              53               3.0
#
# [20630 rows x 7 columns]

# %%
father_df.isnull().sum()
# Out:
# rent         0
# dist         0
# nrooms       0
# age          0
# size         0
# noccup       0
# price     1806
# dtype: int64

# %% [markdown]
# # Add father's columns

# %%
my_df[['father_rent', 'father_dist', 'father_nrooms', 'father_age', 'fayher_size', 'father_noccup']]=father_df[['rent', 'dist', 'nrooms', 'age', 'size', 'noccup']]

# %%
my_df.isnull().sum()
# Out:
# price                 0
# rent_converted        0
# dist_converted        0
# age_converted         0
# nrooms_converted      0
# size_converted        0
# noccup_converted      0
# father_rent         257
# father_dist         257
# father_nrooms       257
# father_age          257
# fayher_size         257
# father_noccup       257
# dtype: int64

# %%
my_df
# Out:
#               price  rent_converted  ...  fayher_size  father_noccup
# 0      226300.00000      624.000000  ...         52.0            3.0
# 1      205797.80438      622.000000  ...         43.0            3.0
# 2      176050.00000      544.000000  ...         57.0            3.0
# 3      170650.00000      423.000000  ...         51.0            3.0
# 4      171100.00000      288.000000  ...         44.0            3.0
# ...             ...             ...  ...          ...            ...
# 20635   39050.00000      117.000000  ...         52.0            3.0
# 20636   38550.00000      191.000000  ...         63.0            3.0
# 20637   46150.00000      127.000000  ...         47.0            3.0
# 20638   42350.00000      140.000000  ...         43.0            3.0
# 20639   44700.00000      289.893963  ...         53.0            3.0
#
# [20630 rows x 13 columns]

# %% [markdown]
# # **Find age diff**

# %%
my_df['diff_age']=my_df['age_converted']-my_df['father_age']
my_df[my_df['diff_age']!=0]
# Out:
#           price  rent_converted  ...  father_noccup      diff_age
# 6      149600.0      289.893963  ...            3.0 -3.953133e-07
# 12     106750.0      230.000000  ...            3.0 -3.953132e-07
# 31      57600.0      147.000000  ...            3.0 -3.953132e-07
# 72      90475.0      131.000000  ...            NaN           NaN
# 73      33750.0       37.000000  ...            3.0 -3.953132e-07
# ...         ...             ...  ...            ...           ...
# 20609   90475.0      172.000000  ...            NaN           NaN
# 20614   29000.0      185.000000  ...            3.0 -3.953133e-07
# 20617   35400.0      289.893963  ...            3.0 -3.953133e-07
# 20618   31700.0      168.000000  ...            3.0 -3.953133e-07
# 20636   38550.0      191.000000  ...            3.0 -3.953133e-07
#
# [1247 rows x 16 columns]

# %%
my_df['diff_age'].isnull().sum()
# Out:
# 257

# %% [markdown]
# # Find rent diff

# %%
my_df['diff_rent']=my_df['rent_converted']-my_df['father_rent']
my_df[my_df['diff_rent']!=0]
# Out:
#                price  rent_converted  ...      diff_age     diff_rent
# 6      149600.000000      289.893963  ... -3.953133e-07  1.517027e-07
# 11     120900.000000      289.893963  ...  0.000000e+00  1.517027e-07
# 34      54850.000000      289.893963  ...  0.000000e+00  1.517027e-07
# 43      94400.000000      289.893963  ...  0.000000e+00  1.517027e-07
# 57      42650.000000      289.893963  ...  0.000000e+00  1.517027e-07
# ...              ...             ...  ...           ...           ...
# 20608   88180.542282      289.893963  ...  0.000000e+00  1.517027e-07
# 20609   90475.000000      172.000000  ...           NaN           NaN
# 20617   35400.000000      289.893963  ... -3.953133e-07  1.517027e-07
# 20634   58400.000000      289.893963  ...  0.000000e+00  1.189396e+01
# 20639   44700.000000      289.893963  ...  0.000000e+00  1.517027e-07
#
# [2719 rows x 17 columns]

# %% [markdown]
# # **Find dist diff**

# %%
my_df['diff_dist']=my_df['dist_converted']-my_df['father_dist']
my_df[my_df['diff_dist']!=0]
# Out:
#           price  rent_converted  ...  diff_rent     diff_dist
# 2      176050.0           544.0  ...        0.0  3.494365e-07
# 14      79600.0           143.0  ...        0.0  3.494365e-07
# 23      49850.0           163.0  ...        0.0  3.494364e-07
# 29      66000.0           126.0  ...        0.0  3.494364e-07
# 37      51950.0           105.0  ...        0.0  3.494364e-07
# ...         ...             ...  ...        ...           ...
# 20620   50000.0           342.0  ...        0.0  3.494364e-07
# 20623   32750.0           211.0  ...        0.0  3.494364e-07
# 20628   46200.0           194.0  ...        0.0  3.494364e-07
# 20632   57800.0           234.0  ...        0.0  3.494365e-07
# 20637   46150.0           127.0  ...        0.0  3.494365e-07
#
# [2240 rows x 18 columns]

# %% [markdown]
# # Nrooms diff

# %%
my_df['diff_nrooms']=my_df['nrooms_converted']-my_df['father_nrooms']
my_df[my_df['diff_nrooms']!=0]
# Out:
#           price  rent_converted  ...  diff_dist   diff_nrooms
# 7      120700.0           234.0  ...        0.0  3.942944e-07
# 18      79350.0           149.0  ...        0.0  3.942944e-07
# 39      88000.0           194.0  ...        0.0  3.942944e-07
# 68      42500.0           138.0  ...        0.0  3.942944e-07
# 70      41250.0           132.0  ...        0.0  3.942944e-07
# ...         ...             ...  ...        ...           ...
# 20590   35650.0           126.0  ...        0.0  3.942944e-07
# 20605   30600.0           137.0  ...        0.0  3.942944e-07
# 20609   90475.0           172.0  ...        NaN           NaN
# 20624   43600.0           230.0  ...        0.0  3.942944e-07
# 20638   42350.0           140.0  ...        0.0  3.942944e-07
#
# [1241 rows x 19 columns]

# %% [markdown]
# # Size diff

# %%
my_df['diff_size']=my_df['size_converted']-my_df['fayher_size']
my_df[my_df['diff_size']!=0]
# Out:
#           price  rent_converted  ...   diff_nrooms  diff_size
# 70      41250.0      132.000000  ...  3.942944e-07  -0.904165
# 72      90475.0      131.000000  ...           NaN        NaN
# 79      90475.0      150.000000  ...           NaN        NaN
# 154    195050.0      611.000000  ...  0.000000e+00  -0.904165
# 210     90475.0      289.893963  ...           NaN        NaN
# ...         ...             ...  ...           ...        ...
# 20470   90475.0      313.000000  ...           NaN        NaN
# 20506   90475.0      520.000000  ...           NaN        NaN
# 20550   90475.0      216.000000  ...           NaN        NaN
# 20601   28950.0      117.000000  ...  0.000000e+00  -0.904165
# 20609   90475.0      172.000000  ...           NaN        NaN
#
# [527 rows x 20 columns]

# %% [markdown]
# # **Find noccup diff**

# %%
my_df['diff_noccup']=my_df['noccup_converted']-my_df['father_noccup']
my_df[my_df['diff_noccup']!=0]
# Out:
#           price  rent_converted  ...  diff_size   diff_noccup
# 40      77700.0      157.000000  ...        0.0  1.758108e-07
# 72      90475.0      131.000000  ...        NaN           NaN
# 79      90475.0      150.000000  ...        NaN           NaN
# 110    131250.0      381.000000  ...        0.0  5.462100e-02
# 138    183350.0      289.893963  ...        0.0  1.758108e-07
# ...         ...             ...  ...        ...           ...
# 20470   90475.0      313.000000  ...        NaN           NaN
# 20480   98050.0      353.000000  ...        0.0  5.462100e-02
# 20506   90475.0      520.000000  ...        NaN           NaN
# 20550   90475.0      216.000000  ...        NaN           NaN
# 20609   90475.0      172.000000  ...        NaN           NaN
#
# [503 rows x 21 columns]

# %%
my_df.sum()
# Out:
# price               2.184426e+09
# rent_converted      5.975718e+06
# dist_converted      2.728210e+05
# age_converted       5.907410e+05
# nrooms_converted    7.069690e+04
# size_converted      1.220096e+06
# noccup_converted    6.301166e+04
# father_rent         5.905487e+06
# father_dist         2.692931e+05
# father_nrooms       6.980907e+04
# father_age          5.834807e+05
# fayher_size         1.200202e+06
# father_noccup       6.223683e+04
# dtype: float64
